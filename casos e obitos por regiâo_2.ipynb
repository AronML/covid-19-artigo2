# %%
from matplotlib import pyplot as plt
import pandas as pd

base = pd.read_excel('covid maio fim.xlsx')

# %%
base.municipio.fillna(0, inplace=True)
base.codmun.fillna(0, inplace=True)
base
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN         0     76       0.0             NaN
# 1             Brasil    NaN         0     76       0.0             NaN
# 2             Brasil    NaN         0     76       0.0             NaN
# 3             Brasil    NaN         0     76       0.0             NaN
# 4             Brasil    NaN         0     76       0.0             NaN
# 5             Brasil    NaN         0     76       0.0             NaN
# 6             Brasil    NaN         0     76       0.0             NaN
# 7             Brasil    NaN         0     76       0.0             NaN
# 8             Brasil    NaN         0     76       0.0             NaN
# 9             Brasil    NaN         0     76       0.0             NaN
# 10            Brasil    NaN         0     76       0.0             NaN
# 11            Brasil    NaN         0     76       0.0             NaN
# ...

# %%
data_mun = base['municipio'] == 0
data_mun2 = base[data_mun]
data_mun3 = data_mun2['codmun'] == 0.0
data = data_mun2[data_mun3]
data
# Out:
#             regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 0           Brasil    NaN         0     76     0.0             NaN
# 1           Brasil    NaN         0     76     0.0             NaN
# 2           Brasil    NaN         0     76     0.0             NaN
# 3           Brasil    NaN         0     76     0.0             NaN
# 4           Brasil    NaN         0     76     0.0             NaN
# 5           Brasil    NaN         0     76     0.0             NaN
# 6           Brasil    NaN         0     76     0.0             NaN
# 7           Brasil    NaN         0     76     0.0             NaN
# 8           Brasil    NaN         0     76     0.0             NaN
# 9           Brasil    NaN         0     76     0.0             NaN
# 10          Brasil    NaN         0     76     0.0             NaN
# 11          Brasil    NaN         0     76     0.0             NaN
# 12          Brasil    NaN         0     76     0.0             NaN
# ...

# %%
data_Norte = data['regiao'] == 'Norte'
data_Norte = data[data_Norte]

data_AL = data['estado'] == 'AL'
data_AL = data[data_AL]

data_RO = data['estado'] == 'RO'
data_RO = data[data_RO]

data_AC = data['estado'] == 'AC'
data_AC = data[data_AC]

data_AM = data['estado'] == 'AM'
data_AM = data[data_AM]

data_RR = data['estado'] == 'RR'
data_RR = data[data_RR]

data_PA = data['estado'] == 'PA'
data_PA = data[data_PA]

data_AP = data['estado'] == 'AP'
data_AP = data[data_AP]

data_TO = data['estado'] == 'TO'
data_TO = data[data_TO]

data_MA = data['estado'] == 'MA'
data_MA = data[data_MA]

data_PI = data['estado'] == 'PI'
data_PI = data[data_PI]

data_CE = data['estado'] == 'CE' 
data_CE = data[data_CE]

data_RN = data['estado'] == 'RN'
data_RN = data[data_RN]

data_PB = data['estado'] == 'PB'
data_PB = data[data_PB]

data_PE = data['estado'] == 'PE'
data_PE = data[data_PE]

data_SE = data['estado'] == 'SE'
data_SE = data[data_SE]

data_BA = data['estado'] == 'BA'
data_BA = data[data_BA]

data_MG = data['estado'] == 'MG'
data_MG = data[data_MG]

data_ES = data['estado'] == 'ES'
data_ES = data[data_ES]

data_RJ = data['estado'] == 'RJ'
data_RJ = data[data_RJ]

data_SP = data['estado'] == 'SP'
data_SP = data[data_SP]

data_PR = data['estado'] == 'PR'
data_PR = data[data_PR]

data_SC = data['estado'] == 'SC'
data_SC = data[data_SC]

data_RS = data['estado'] == 'RS'
data_RS = data[data_RS]

data_MS = data['estado'] == 'MS'
data_MS = data[data_MS]

data_MT = data['estado'] == 'MT'
data_MT = data[data_MT]

data_GO = data['estado'] == 'GO'
data_GO = data[data_GO]

data_DF = data['estado'] == 'DF'
data_DF = data[data_DF]

data_CE
# Out:
#        regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 748  Nordeste     CE         0     23     0.0             NaN             NaN
# 749  Nordeste     CE         0     23     0.0             NaN             NaN
# 750  Nordeste     CE         0     23     0.0             NaN             NaN
# 751  Nordeste     CE         0     23     0.0             NaN             NaN
# 752  Nordeste     CE         0     23     0.0             NaN             NaN
# 753  Nordeste     CE         0     23     0.0             NaN             NaN
# 754  Nordeste     CE         0     23     0.0             NaN             NaN
# 755  Nordeste     CE         0     23     0.0             NaN             NaN
# 756  Nordeste     CE         0     23     0.0             NaN             NaN
# 757  Nordeste     CE         0     23     0.0             NaN             NaN
# 758  Nordeste     CE         0     23     0.0             NaN             NaN
# ...

# %%
plt.plot(data_MA['data'],data_MA['casosAcumulado'])
plt.plot(data_PI['data'],data_PI['casosAcumulado'])
plt.plot(data_CE['data'],data_CE['casosAcumulado'])
plt.plot(data_RN['data'],data_RN['casosAcumulado'])
plt.plot(data_PB['data'],data_PB['casosAcumulado'])
plt.plot(data_PE['data'],data_PE['casosAcumulado'])
plt.plot(data_AL['data'],data_AL['casosAcumulado'])
plt.plot(data_SE['data'],data_SE['casosAcumulado'])
plt.plot(data_BA['data'],data_BA['casosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de casos - Região Nordeste')
plt.legend(['MA','PI','CE','RN','PB','PE','AL','SE','BA'])
plt.grid()
plt.savefig('total_casos_nordeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_PR['data'],data_PR['casosAcumulado'])
plt.plot(data_SC['data'],data_SC['casosAcumulado'])
plt.plot(data_RS['data'],data_RS['casosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de casos - Região Sul')
plt.legend(['PR','SC','RS'])
plt.grid()
plt.savefig('total_casos_sul.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_MG['data'],data_MG['casosAcumulado'])
plt.plot(data_ES['data'],data_ES['casosAcumulado'])
plt.plot(data_RJ['data'],data_RJ['casosAcumulado'])
plt.plot(data_SP['data'],data_SP['casosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de casos - Região Sudeste')
plt.legend(['MG','ES','RJ','SP'])
plt.grid()

plt.savefig('total_casos_sudeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_MS['data'],data_MS['casosAcumulado'])
plt.plot(data_MT['data'],data_MT['casosAcumulado'])
plt.plot(data_GO['data'],data_GO['casosAcumulado'])
plt.plot(data_DF['data'],data_DF['casosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de casos - Região Centro-Oeste')
plt.legend(['MS','MT','GO','DF'])
plt.grid()
plt.savefig('total_casos_centroeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_AC['data'],data_AC['casosAcumulado'])
plt.plot(data_RO['data'],data_RO['casosAcumulado'])
plt.plot(data_AM['data'],data_AM['casosAcumulado'])
plt.plot(data_RR['data'],data_RR['casosAcumulado'])
plt.plot(data_PA['data'],data_PA['casosAcumulado'])
plt.plot(data_AP['data'],data_AP['casosAcumulado'])
plt.plot(data_TO['data'],data_TO['casosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de casos - Região Norte')
plt.legend(['AC','RO','AM','RR','PA','AP','TO'])
plt.grid()
plt.savefig('total_casos_norte.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_MA['data'],data_MA['obitosAcumulado'])
plt.plot(data_PI['data'],data_PI['obitosAcumulado'])
plt.plot(data_CE['data'],data_CE['obitosAcumulado'])
plt.plot(data_RN['data'],data_RN['obitosAcumulado'])
plt.plot(data_PB['data'],data_PB['obitosAcumulado'])
plt.plot(data_PE['data'],data_PE['obitosAcumulado'])
plt.plot(data_AL['data'],data_AL['obitosAcumulado'])
plt.plot(data_SE['data'],data_SE['obitosAcumulado'])
plt.plot(data_BA['data'],data_BA['obitosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de obitos - Região Nordeste')
plt.legend(['MA','PI','CE','RN','PB','PE','AL','SE','BA'])
plt.grid()
plt.savefig('total_obitos_nordeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_PR['data'],data_PR['obitosAcumulado'])
plt.plot(data_SC['data'],data_SC['obitosAcumulado'])
plt.plot(data_RS['data'],data_RS['obitosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de obitos - Região Sul')
plt.legend(['PR','SC','RS'])
plt.grid()
plt.savefig('total_obitos_sul.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_MG['data'],data_MG['obitosAcumulado'])
plt.plot(data_ES['data'],data_ES['obitosAcumulado'])
plt.plot(data_RJ['data'],data_RJ['obitosAcumulado'])
plt.plot(data_SP['data'],data_SP['obitosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de obitos - Região Sudeste')
plt.legend(['MG','ES','RJ','SP'])
plt.grid()
plt.savefig('total_obitos_sudeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_MS['data'],data_MS['obitosAcumulado'])
plt.plot(data_MT['data'],data_MT['obitosAcumulado'])
plt.plot(data_GO['data'],data_GO['obitosAcumulado'])
plt.plot(data_DF['data'],data_DF['obitosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de obitos - Região Centro-Oeste')
plt.legend(['MS','MT','GO','DF'])
plt.grid()
plt.savefig('total_obitos_centroeste.png',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_AC['data'],data_AC['obitosAcumulado'])
plt.plot(data_RO['data'],data_RO['obitosAcumulado'])
plt.plot(data_AM['data'],data_AM['obitosAcumulado'])
plt.plot(data_RR['data'],data_RR['obitosAcumulado'])
plt.plot(data_PA['data'],data_PA['obitosAcumulado'])
plt.plot(data_AP['data'],data_AP['obitosAcumulado'])
plt.plot(data_TO['data'],data_TO['obitosAcumulado'])
plt.xticks(['2020-03-01','2020-03-10','2020-03-20','2020-03-30','2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Total de óbitos - Região Norte')
plt.legend(['AC','RO','AM','RR','PA','AP','TO'])
plt.grid()
plt.savefig('total_obitos_norte.png',bbox_inches='tight')
plt.show()
