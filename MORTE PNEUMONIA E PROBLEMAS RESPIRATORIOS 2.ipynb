# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('brasilio_maio.csv')

# %%
data
# Out:
#             date state  epidemiological_week_2020  deaths_total_2019  \
# 0     2020-12-31    AC                         53               3382
# 1     2020-12-31    AL                         53              14277
# 2     2020-12-31    AM                         53              12593
# 3     2020-12-31    AP                         53               2068
# 4     2020-12-31    BA                         53              56380
# 5     2020-12-31    CE                         53              38005
# 6     2020-12-31    DF                         53              13942
# 7     2020-12-31    ES                         53              22914
# 8     2020-12-31    GO                         53              28538
# 9     2020-12-31    MA                         53              16571
# 10    2020-12-31    MG                         53             114905
# 11    2020-12-31    MS                         53              14755
# 12    2020-12-31    MT                         53              11887
# ...

# %%
data_SP = data[data['state'] == 'SP']
data_SP = data_SP[data_SP['date'] < '2020-05-30']

# %%
data_SP_total = data_SP.sort_values('date', ascending = True)

# %%
data_SP_total
# Out:
#             date state  epidemiological_week_2020  deaths_total_2019  \
# 9879  2020-01-01    SP                          1                802
# 9852  2020-01-02    SP                          1               1590
# 9825  2020-01-03    SP                          1               2429
# 9798  2020-01-04    SP                          1               3203
# 9771  2020-01-05    SP                          2               3979
# 9744  2020-01-06    SP                          2               4711
# 9717  2020-01-07    SP                          2               5466
# 9690  2020-01-08    SP                          2               6268
# 9663  2020-01-09    SP                          2               7069
# 9636  2020-01-10    SP                          2               7922
# 9609  2020-01-11    SP                          2               8725
# 9582  2020-01-12    SP                          3               9517
# 9555  2020-01-13    SP                          3              10302
# ...

# %%
plt.scatter(data_SP_total['date'], data_SP_total['deaths_pneumonia_2019'])
plt.scatter(data_SP_total['date'], data_SP_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por pneumonia - SP')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_SP.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SP_total['date'], data_SP_total['deaths_respiratory_failure_2019'])
plt.scatter(data_SP_total['date'], data_SP_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - SP')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_SP.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SP_total['date'], data_SP_total['deaths_indeterminate_2019'])
plt.scatter(data_SP_total['date'], data_SP_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - SP')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_SP.png',bbox_inches='tight')
plt.show()

# %%
data_AM = data[data['state'] == 'AM']
data_AM = data_AM[data_AM['date'] < '2020-05-30']
data_AM_total = data_AM.sort_values('date', ascending = True)
data_AM_total = data_AM_total

# %%
plt.scatter(data_AM_total['date'], data_AM_total['deaths_pneumonia_2019'])
plt.scatter(data_AM_total['date'], data_AM_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por pneumonia - AM')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_AM.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AM_total['date'], data_AM_total['deaths_respiratory_failure_2019'])
plt.scatter(data_AM_total['date'], data_AM_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - AM')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_AM.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AM_total['date'], data_AM_total['deaths_indeterminate_2019'])
plt.scatter(data_AM_total['date'], data_AM_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Causas Indeterminadas - AM')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_ind_AM.png',bbox_inches='tight')
plt.show()

# %%
data_AC = data[data['state'] == 'AC']
data_AC = data_AC[data_AC['date'] < '2020-05-30']
data_AC_total = data_AC.sort_values('date', ascending = True)
data_AC_total = data_AC_total
data_AC_total
# Out:
#             date state  epidemiological_week_2020  deaths_total_2019  \
# 9854  2020-01-01    AC                          1                 10
# 9827  2020-01-02    AC                          1                 17
# 9800  2020-01-03    AC                          1                 25
# 9773  2020-01-04    AC                          1                 30
# 9746  2020-01-05    AC                          2                 36
# 9719  2020-01-06    AC                          2                 44
# 9692  2020-01-07    AC                          2                 53
# 9665  2020-01-08    AC                          2                 60
# 9638  2020-01-09    AC                          2                 67
# 9611  2020-01-10    AC                          2                 72
# 9584  2020-01-11    AC                          2                 82
# 9557  2020-01-12    AC                          3                 93
# 9530  2020-01-13    AC                          3                102
# ...

# %%
data_AC = data[data['state'] == 'AC']
data_AC = data_AC[data_AC['date'] < '2020-05-30']
data_AC_total = data_AC.sort_values('date', ascending = True)
data_AC_total = data_AC_total
data_AC_total

plt.scatter(data_AC_total['date'], data_AC_total['deaths_respiratory_failure_2019'])
plt.scatter(data_AC_total['date'], data_AC_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - AC')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_AC.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AC_total['date'], data_AC_total['deaths_pneumonia_2019'])
plt.scatter(data_AC_total['date'], data_AC_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - AC')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_AC.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AC_total['date'], data_AC_total['deaths_indeterminate_2019'])
plt.scatter(data_AC_total['date'], data_AC_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - AC')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_AC.png',bbox_inches='tight')
plt.show()

# %%
data_AL = data[data['state'] == 'AL']
data_AL = data_AL[data_AL['date'] < '2020-05-30']
data_AL_total = data_AL.sort_values('date', ascending = True)
data_AL_total = data_AL_total

plt.scatter(data_AL_total['date'], data_AL_total['deaths_pneumonia_2019'])
plt.scatter(data_AL_total['date'], data_AL_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - AL')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_AL.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AL_total['date'], data_AL_total['deaths_respiratory_failure_2019'])
plt.scatter(data_AL_total['date'], data_AL_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - AL')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_falha_AL.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AL_total['date'], data_AL_total['deaths_indeterminate_2019'])
plt.scatter(data_AL_total['date'], data_AL_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - AL')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_AL.png',bbox_inches='tight')
plt.show()

# %%
data_AP = data[data['state'] == 'AP']
data_AP = data_AP[data_AP['date'] < '2020-05-30']
data_AP_total = data_AP.sort_values('date', ascending = True)
data_AP_total = data_AP_total

plt.scatter(data_AP_total['date'], data_AP_total['deaths_pneumonia_2019'])
plt.scatter(data_AP_total['date'], data_AP_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - AP')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_AP.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AP_total['date'], data_AP_total['deaths_respiratory_failure_2019'])
plt.scatter(data_AP_total['date'], data_AP_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - AP')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_AP.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_AP_total['date'], data_AP_total['deaths_indeterminate_2019'])
plt.scatter(data_AP_total['date'], data_AP_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - AP')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_AP.png',bbox_inches='tight')
plt.show()

# %%
data_BA = data[data['state'] == 'BA']
data_BA = data_BA[data_BA['date'] < '2020-05-30']
data_BA_total = data_BA.sort_values('date', ascending = True)
data_BA_total = data_BA_total

plt.scatter(data_BA_total['date'], data_BA_total['deaths_respiratory_failure_2019'])
plt.scatter(data_BA_total['date'], data_BA_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - BA')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_BA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_BA_total['date'], data_BA_total['deaths_pneumonia_2019'])
plt.scatter(data_BA_total['date'], data_BA_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - BA')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_BA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_BA_total['date'], data_BA_total['deaths_indeterminate_2019'])
plt.scatter(data_BA_total['date'], data_BA_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - BA')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_BA.png',bbox_inches='tight')
plt.show()

# %%
data_CE = data[data['state'] == 'CE']
data_CE = data_CE[data_CE['date'] < '2020-05-30']
data_CE_total = data_CE.sort_values('date', ascending = True)
data_CE_total = data_CE_total

plt.scatter(data_CE_total['date'], data_CE_total['deaths_pneumonia_2019'])
plt.scatter(data_CE_total['date'], data_CE_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - CE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_CE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_CE_total['date'], data_CE_total['deaths_respiratory_failure_2019'])
plt.scatter(data_CE_total['date'], data_CE_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - CE')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_CE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_CE_total['date'], data_CE_total['deaths_indeterminate_2019'])
plt.scatter(data_CE_total['date'], data_CE_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - CE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_CE.png',bbox_inches='tight')
plt.show()

# %%
data_DF = data[data['state'] == 'DF']
data_DF = data_DF[data_DF['date'] < '2020-05-30']
data_DF_total = data_DF.sort_values('date', ascending = True)
data_DF_total = data_DF_total

plt.scatter(data_DF_total['date'], data_DF_total['deaths_respiratory_failure_2019'])
plt.scatter(data_DF_total['date'], data_DF_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - DF')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_DF.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_DF_total['date'], data_DF_total['deaths_pneumonia_2019'])
plt.scatter(data_DF_total['date'], data_DF_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - DF')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_DF.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_DF_total['date'], data_DF_total['deaths_indeterminate_2019'])
plt.scatter(data_DF_total['date'], data_DF_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - DF')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_DF.png',bbox_inches='tight')
plt.show()

# %%
data_ES = data[data['state'] == 'ES']
data_ES = data_ES[data_ES['date'] < '2020-05-30']
data_ES_total = data_ES.sort_values('date', ascending = True)
data_ES_total = data_ES_total

plt.scatter(data_ES_total['date'], data_ES_total['deaths_pneumonia_2019'])
plt.scatter(data_ES_total['date'], data_ES_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - ES')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_ES.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_ES_total['date'], data_ES_total['deaths_respiratory_failure_2019'])
plt.scatter(data_ES_total['date'], data_ES_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - ES')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_ES.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_ES_total['date'], data_ES_total['deaths_indeterminate_2019'])
plt.scatter(data_ES_total['date'], data_ES_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - ES')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_ES.png',bbox_inches='tight')
plt.show()

# %%
data_GO = data[data['state'] == 'GO']
data_GO = data_GO[data_GO['date'] < '2020-05-30']
data_GO_total = data_GO.sort_values('date', ascending = True)

plt.scatter(data_GO_total['date'], data_GO_total['deaths_respiratory_failure_2019'])
plt.scatter(data_GO_total['date'], data_GO_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - GO')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_GO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_GO_total['date'], data_GO_total['deaths_pneumonia_2019'])
plt.scatter(data_GO_total['date'], data_GO_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - GO')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_GO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_GO_total['date'], data_GO_total['deaths_indeterminate_2019'])
plt.scatter(data_GO_total['date'], data_GO_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - GO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_GO.png',bbox_inches='tight')
plt.show()

# %%
data_MA = data[data['state'] == 'MA']
data_MA = data_MA[data_MA['date'] < '2020-05-30']
data_MA_total = data_MA.sort_values('date', ascending = True)


plt.scatter(data_MA_total['date'], data_MA_total['deaths_respiratory_failure_2019'])
plt.scatter(data_MA_total['date'], data_MA_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - MA')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_MA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MA_total['date'], data_MA_total['deaths_pneumonia_2019'])
plt.scatter(data_MA_total['date'], data_MA_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - MA')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_MA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MA_total['date'], data_MA_total['deaths_indeterminate_2019'])
plt.scatter(data_MA_total['date'], data_MA_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - MA')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_MA.png',bbox_inches='tight')
plt.show()

# %%
data_MG = data[data['state'] == 'MG']
data_MG = data_MG[data_MG['date'] < '2020-05-30']
data_MG_total = data_MG.sort_values('date', ascending = True)

plt.scatter(data_MG_total['date'], data_MG_total['deaths_respiratory_failure_2019'])
plt.scatter(data_MG_total['date'], data_MG_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - MG')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_MG.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MG_total['date'], data_MG_total['deaths_pneumonia_2019'])
plt.scatter(data_MG_total['date'], data_MG_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - MG')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_MG.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MG_total['date'], data_MG_total['deaths_indeterminate_2019'])
plt.scatter(data_MG_total['date'], data_MG_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - MG')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_MG.png',bbox_inches='tight')
plt.show()

# %%
data_MS = data[data['state'] == 'MS']
data_MS = data_MS[data_MS['date'] < '2020-05-30']
data_MS_total = data_MS.sort_values('date', ascending = True)


plt.scatter(data_MS_total['date'], data_MS_total['deaths_respiratory_failure_2019'])
plt.scatter(data_MS_total['date'], data_MS_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - MS')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_falha_MS.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MS_total['date'], data_MS_total['deaths_pneumonia_2019'])
plt.scatter(data_MS_total['date'], data_MS_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - MS')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_MS.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MS_total['date'], data_MS_total['deaths_indeterminate_2019'])
plt.scatter(data_MS_total['date'], data_MS_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - MS')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_MS.png',bbox_inches='tight')
plt.show()

# %%
data_MT = data[data['state'] == 'MT']
data_MT = data_MT[data_MT['date'] < '2020-05-30']
data_MT_total = data_MT.sort_values('date', ascending = True)


plt.scatter(data_MT_total['date'], data_MT_total['deaths_respiratory_failure_2019'])
plt.scatter(data_MT_total['date'], data_MT_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - MT')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_MT.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MT_total['date'], data_MT_total['deaths_pneumonia_2019'])
plt.scatter(data_MT_total['date'], data_MT_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - MT')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_MT.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_MT_total['date'], data_MT_total['deaths_indeterminate_2019'])
plt.scatter(data_MT_total['date'], data_MT_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - MT')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_MT.png',bbox_inches='tight')
plt.show()

# %%
data_PA = data[data['state'] == 'PA']
data_PA = data_PA[data_PA['date'] < '2020-05-30']
data_PA_total = data_PA.sort_values('date', ascending = True)


plt.scatter(data_PA_total['date'], data_PA_total['deaths_respiratory_failure_2019'])
plt.scatter(data_PA_total['date'], data_PA_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - PA')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_PA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PA_total['date'], data_PA_total['deaths_pneumonia_2019'])
plt.scatter(data_PA_total['date'], data_PA_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - PA')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_PA.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PA_total['date'], data_PA_total['deaths_indeterminate_2019'])
plt.scatter(data_PA_total['date'], data_PA_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - PA')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_PA.png',bbox_inches='tight')
plt.show()

# %%
data_PB = data[data['state'] == 'PB']
data_PB = data_PB[data_PB['date'] < '2020-05-30']
data_PB_total = data_PB.sort_values('date', ascending = True)

plt.scatter(data_PB_total['date'], data_PB_total['deaths_respiratory_failure_2019'])
plt.scatter(data_PB_total['date'], data_PB_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - PB')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_PB.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PB_total['date'], data_PB_total['deaths_pneumonia_2019'])
plt.scatter(data_PB_total['date'], data_PB_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - PB')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_PB.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PB_total['date'], data_PB_total['deaths_indeterminate_2019'])
plt.scatter(data_PB_total['date'], data_PB_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - PB')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_PB.png',bbox_inches='tight')
plt.show()

# %%
data_PE = data[data['state'] == 'PE']
data_PE = data_PE[data_PE['date'] < '2020-05-30']
data_PE_total = data_PE.sort_values('date', ascending = True)


plt.scatter(data_PE_total['date'], data_PE_total['deaths_respiratory_failure_2019'])
plt.scatter(data_PE_total['date'], data_PE_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - PE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_falha_PE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PE_total['date'], data_PE_total['deaths_pneumonia_2019'])
plt.scatter(data_PE_total['date'], data_PE_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - PE')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_PE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PE_total['date'], data_PE_total['deaths_indeterminate_2019'])
plt.scatter(data_PE_total['date'], data_PE_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - PE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_PE.png',bbox_inches='tight')
plt.show()

# %%
data_PI = data[data['state'] == 'PI']
data_PI = data_PI[data_PI['date'] < '2020-05-30']
data_PI_total = data_PI.sort_values('date', ascending = True)


plt.scatter(data_PI_total['date'], data_PI_total['deaths_respiratory_failure_2019'])
plt.scatter(data_PI_total['date'], data_PI_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - PI')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_PI.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PI_total['date'], data_PI_total['deaths_pneumonia_2019'])
plt.scatter(data_PI_total['date'], data_PI_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - PI')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_PI.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PI_total['date'], data_PI_total['deaths_indeterminate_2019'])
plt.scatter(data_PI_total['date'], data_PI_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - PI')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_PI.png',bbox_inches='tight')
plt.show()

# %%
data_PR = data[data['state'] == 'PR']
data_PR = data_PR[data_PR['date'] < '2020-05-30']
data_PR_total = data_PR.sort_values('date', ascending = True)


plt.scatter(data_PR_total['date'], data_PR_total['deaths_respiratory_failure_2019'])
plt.scatter(data_PR_total['date'], data_PR_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - PR')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_PR.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PR_total['date'], data_PR_total['deaths_pneumonia_2019'])
plt.scatter(data_PR_total['date'], data_PR_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - PR')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_pneumonia_PR.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_PR_total['date'], data_PR_total['deaths_indeterminate_2019'])
plt.scatter(data_PR_total['date'], data_PR_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - PR')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_PR.png',bbox_inches='tight')
plt.show()

# %%
data_RJ = data[data['state'] == 'RJ']
data_RJ = data_RJ[data_RJ['date'] < '2020-05-30']
data_RJ_total = data_RJ.sort_values('date', ascending = True)


plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_respiratory_failure_2019'])
plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - RJ')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_RJ.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_pneumonia_2019'])
plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - RJ')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_RJ.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_indeterminate_2019'])
plt.scatter(data_RJ_total['date'], data_RJ_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - RJ')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_RJ.png',bbox_inches='tight')
plt.show()

# %%
data_RN = data[data['state'] == 'RN']
data_RN = data_RN[data_RN['date'] < '2020-05-30']
data_RN_total = data_RN.sort_values('date', ascending = True)


plt.scatter(data_RN_total['date'], data_RN_total['deaths_respiratory_failure_2019'])
plt.scatter(data_RN_total['date'], data_RN_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - RN')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_RN.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RN_total['date'], data_RN_total['deaths_pneumonia_2019'])
plt.scatter(data_RN_total['date'], data_RN_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - RN')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_RN.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RN_total['date'], data_RN_total['deaths_indeterminate_2019'])
plt.scatter(data_RN_total['date'], data_RN_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - RN')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_RN.png',bbox_inches='tight')
plt.show()

# %%
data_RO = data[data['state'] == 'RO']
data_RO = data_RO[data_RO['date'] < '2020-05-30']
data_RO_total = data_RO.sort_values('date', ascending = True)

plt.scatter(data_RO_total['date'], data_RO_total['deaths_respiratory_failure_2019'])
plt.scatter(data_RO_total['date'], data_RO_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - RO')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_RO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RO_total['date'], data_RO_total['deaths_pneumonia_2019'])
plt.scatter(data_RO_total['date'], data_RO_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - RO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_RO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RO_total['date'], data_RO_total['deaths_indeterminate_2019'])
plt.scatter(data_RO_total['date'], data_RO_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - RO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_RO.png',bbox_inches='tight')
plt.show()

# %%
data_RR = data[data['state'] == 'RR']
data_RR = data_RR[data_RR['date'] < '2020-05-30']
data_RR_total = data_RR.sort_values('date', ascending = True)

plt.scatter(data_RR_total['date'], data_RR_total['deaths_respiratory_failure_2019'])
plt.scatter(data_RR_total['date'], data_RR_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - RR')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_RR.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RR_total['date'], data_RR_total['deaths_pneumonia_2019'])
plt.scatter(data_RR_total['date'], data_RR_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - RR')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_RR.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RR_total['date'], data_RR_total['deaths_indeterminate_2019'])
plt.scatter(data_RR_total['date'], data_RR_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - RR')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_RR.png',bbox_inches='tight')
plt.show()

# %%
data_RS = data[data['state'] == 'RS']
data_RS = data_RS[data_RS['date'] < '2020-05-30']
data_RS_total = data_RS.sort_values('date', ascending = True)

plt.scatter(data_RS_total['date'], data_RS_total['deaths_respiratory_failure_2019'])
plt.scatter(data_RS_total['date'], data_RS_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - RS')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_RS.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RS_total['date'], data_RS_total['deaths_pneumonia_2019'])
plt.scatter(data_RS_total['date'], data_RS_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - RS')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_RS.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_RS_total['date'], data_RS_total['deaths_indeterminate_2019'])
plt.scatter(data_RS_total['date'], data_RS_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - RS')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_RS.png',bbox_inches='tight')
plt.show()

# %%
data_SC = data[data['state'] == 'SC']
data_SC = data_SC[data_SC['date'] < '2020-05-30']
data_SC_total = data_SC.sort_values('date', ascending = True)

plt.scatter(data_SC_total['date'], data_SC_total['deaths_respiratory_failure_2019'])
plt.scatter(data_SC_total['date'], data_SC_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - SC')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_SC.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SC_total['date'], data_SC_total['deaths_pneumonia_2019'])
plt.scatter(data_SC_total['date'], data_SC_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - SC')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_SC.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SC_total['date'], data_SC_total['deaths_indeterminate_2019'])
plt.scatter(data_SC_total['date'], data_SC_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - SC')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_SC.png',bbox_inches='tight')
plt.show()

# %%
data_SE = data[data['state'] == 'SE']
data_SE = data_SE[data_SE['date'] < '2020-05-30']
data_SE_total = data_SE.sort_values('date', ascending = True)
data_SE_total = data_SE_total


plt.scatter(data_SE_total['date'], data_SE_total['deaths_respiratory_failure_2019'])
plt.scatter(data_SE_total['date'], data_SE_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - SE')
plt.legend(['2019','2020'])
plt.grid()

plt.savefig('total_obitos_falha_SE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SE_total['date'], data_SE_total['deaths_pneumonia_2019'])
plt.scatter(data_SE_total['date'], data_SE_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - SE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_SE.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_SE_total['date'], data_SE_total['deaths_indeterminate_2019'])
plt.scatter(data_SE_total['date'], data_SE_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - SE')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_SE.png',bbox_inches='tight')
plt.show()

# %%
data_TO = data[data['state'] == 'TO']
data_TO = data_TO[data_TO['date'] < '2020-05-30']
data_TO_total = data_TO.sort_values('date', ascending = True)



plt.scatter(data_TO_total['date'], data_TO_total['deaths_respiratory_failure_2019'])
plt.scatter(data_TO_total['date'], data_TO_total['deaths_respiratory_failure_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Falhas respiratórias - TO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_falha_TO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_TO_total['date'], data_TO_total['deaths_pneumonia_2019'])
plt.scatter(data_TO_total['date'], data_TO_total['deaths_pneumonia_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por Pneumonia - TO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_pneumonia_TO.png',bbox_inches='tight')
plt.show()

# %%
plt.scatter(data_TO_total['date'], data_TO_total['deaths_indeterminate_2019'])
plt.scatter(data_TO_total['date'], data_TO_total['deaths_indeterminate_2020'])
plt.xticks(['2020-01-01','2020-01-10','2020-01-20','2020-01-30','2020-02-10'
            ,'2020-02-20','2020-03-01','2020-03-10','2020-03-20','2020-03-30',
            '2020-04-10','2020-04-20','2020-04-30','2020-05-10','2020-05-20','2020-05-30'], rotation = 90)
plt.title('Mortes por causas indeterminadas - TO')
plt.legend(['2019','2020'])
plt.grid()
plt.savefig('total_obitos_indeterminate_TO.png',bbox_inches='tight')
plt.show()
